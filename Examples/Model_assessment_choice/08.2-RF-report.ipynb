# %% [markdown]
# # **PyTerK** / 08.2-RF-report
# ----
# An Python Iterated K-fold cross validation with shuffling

# %%
import sys
sys.path.append('../..')

import pyterk.config   as config
import pyterk.reporter as reporter

# %% [markdown]
# **Notes :**
#  - Pas de données history (sklearn)
#  - L'axe des x pour les distributions sont en mode auto car variables (E, H, CI oi IQ)

# %%
settings = config.load('08.2-RF-settings.yml', verbose=1)

reporter.show_run_reports(settings,
                          sections   = ['title','context','args','settings','evaluation', 'monitoring', 'distribution', 'correlation'],
                          args       = ['dataset_id','model_id', 'batch_size'],
                          evaluation = ['all'],
                          history      = [ dict(metric='mae', figsize=(8,6), savefig=True, mplstyle='pyterk') ],
                          distribution = [ dict(metric_id=2, min=None,max=None, bins=10, figsize=(8,6), savefig=True, mplstyle='pyterk') ])
# Out:
# <br>**Pyterk - A Python iterative KFold stuff...**
# settings     : 08.2-RF-settings.yml
# description  : Test of random forrest architecture.
# settings v.  : 1.0
# seed         : 123
# datasets_dir : /Users/elisegarel/Desktop/PUBLI/datasets//./
# run_dir      : /Users/elisegarel/Desktop/PUBLI/run//./campaign08/RF_r
# file         : 08.2-RF-settings.yml
# <br>**Load datasets...**
# compo_E_wo_outliers : dd5792e42c250582aef28aa1b4250873b641d5017b4a486c0a54cada5cd04db5 (sha256)
# compo_H_wo_outliers : bf05c1cef9181bdf65d791d8148e16b1620da5a41eca1f5a47f5893b48053a07 (sha256)
# ** WARNING : Dataset compo_CI have 2 missing value(s) !
# compo_CI     : 9bd13906829bbf95a356b255a4094675efacd5ac66a0ceb00d523df7b29a889d (sha256)
# ** WARNING : Dataset compo_IQ have 2 missing value(s) !
# compo_IQ     : a0c059122183e985552dd1e1856ebb40810ef47ccaabee07a8472d0aa19a28ed (sha256)
# <a name="Sommaire"></a>
# ## Sommaire
# ### 1. Short reports
# ...

# %% [markdown]
# ---
# ### PyTerK 2021
